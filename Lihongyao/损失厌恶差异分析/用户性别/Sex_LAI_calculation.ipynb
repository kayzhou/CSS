# %%
import math
import lmfit
import json
import time
from datetime import datetime
from dateutil import parser
import os
import numpy as np
import pandas as pd
from pandas import Series
from scipy import optimize
from matplotlib import ticker
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from scipy.optimize import leastsq

# %% [markdown]
# 成分指数

# %%
blog_time = []
mood = []
gender = []
location = []

for line in open('C:/Users/Lenovo/yan/D/金融数据整理（2021）/原始数据/成分指数.txt', encoding="utf8"):
    w = json.loads(line)
    for key in w.keys():
        if key == 'w:created_at':
            blog_time.append(w[key])
        elif key == 'w:mood':
            mood.append(w[key])
        elif key == 'w:gender':
            gender.append(w[key])
        elif key == 'w:location':
            location.append(w[key])

bmgl = {"blog_time":blog_time,"gender":gender,'mood':mood,"location":location}

bmgl = pd.DataFrame(bmgl)  
bmgl['blog_time'] = pd.to_datetime(bmgl['blog_time'])
bmgl['blog_time'] = bmgl['blog_time'].apply(lambda x : x.strftime('%Y-%m-%d'))
bmgl = bmgl.sort_values(by='blog_time',ascending=True)
bmgl.to_csv(f'C:/Users/Lenovo/yan/D/金融数据整理（2021）/bmgl/bmgl_ingre.csv',index=False, encoding='utf_8_sig')

# %% [markdown]
# 股票

# %%
blog_time = []
mood = []
gender = []
location = []

for line in open('C:/Users/Lenovo/yan/D/金融数据整理（2021）/原始数据/股票.txt', encoding="utf8"):
    w = json.loads(line)
    for key in w.keys():
        if key == 'w:created_at':
            blog_time.append(w[key])
        elif key == 'w:mood':
            mood.append(w[key])
        elif key == 'w:gender':
            gender.append(w[key])
        elif key == 'w:location':
            location.append(w[key])

bmgl = {"blog_time":blog_time,"gender":gender,'mood':mood,"location":location}

bmgl = pd.DataFrame(bmgl)  
bmgl['blog_time'] = pd.to_datetime(bmgl['blog_time'])
bmgl['blog_time'] = bmgl['blog_time'].apply(lambda x : x.strftime('%Y-%m-%d'))
bmgl = bmgl.sort_values(by='blog_time',ascending=True)
bmgl.to_csv(f'C:/Users/Lenovo/yan/D/金融数据整理（2021）/bmgl/bmgl_st.csv',index=False, encoding='utf_8_sig')

# %% [markdown]
# 股市

# %%
blog_time = []
mood = []
gender = []
location = []

for line in open('C:/Users/Lenovo/yan/D/金融数据整理（2021）/原始数据/股市.txt', encoding="utf8"):
    w = json.loads(line)
    for key in w.keys():
        if key == 'w:created_at':
            blog_time.append(w[key])
        elif key == 'w:mood':
            mood.append(w[key])
        elif key == 'w:gender':
            gender.append(w[key])
        elif key == 'w:location':
            location.append(w[key])

bmgl = {"blog_time":blog_time,"gender":gender,'mood':mood,"location":location}

bmgl = pd.DataFrame(bmgl)  
bmgl['blog_time'] = pd.to_datetime(bmgl['blog_time'])
bmgl['blog_time'] = bmgl['blog_time'].apply(lambda x : x.strftime('%Y-%m-%d'))
bmgl = bmgl.sort_values(by='blog_time',ascending=True)
bmgl.to_csv(f'C:/Users/Lenovo/yan/D/金融数据整理（2021）/bmgl/bmgl_sm.csv',index=False, encoding='utf_8_sig')

# %% [markdown]
# 深成指

# %%
blog_time = []
mood = []
gender = []
location = []

for line in open('C:/Users/Lenovo/yan/D/金融数据整理（2021）/原始数据/深成指.txt', encoding="utf8"):
    w = json.loads(line)
    for key in w.keys():
        if key == 'w:created_at':
            blog_time.append(w[key])
        elif key == 'w:mood':
            mood.append(w[key])
        elif key == 'w:gender':
            gender.append(w[key])
        elif key == 'w:location':
            location.append(w[key])

bmgl = {"blog_time":blog_time,"gender":gender,'mood':mood,"location":location}

bmgl = pd.DataFrame(bmgl)  
bmgl['blog_time'] = pd.to_datetime(bmgl['blog_time'])
bmgl['blog_time'] = bmgl['blog_time'].apply(lambda x : x.strftime('%Y-%m-%d'))
bmgl = bmgl.sort_values(by='blog_time',ascending=True)
bmgl.to_csv(f'C:/Users/Lenovo/yan/D/金融数据整理（2021）/bmgl/bmgl_sz.csv',index=False, encoding='utf_8_sig')

# %% [markdown]
# 上证指数

# %%
blog_time = []
mood = []
gender = []
location = []

for line in open('C:/Users/Lenovo/yan/D/金融数据整理（2021）/原始数据/上证指数.txt', encoding="utf8"):
    w = json.loads(line)
    for key in w.keys():
        if key == 'w:created_at':
            blog_time.append(w[key])
        elif key == 'w:mood':
            mood.append(w[key])
        elif key == 'w:gender':
            gender.append(w[key])
        elif key == 'w:location':
            location.append(w[key])

bmgl = {"blog_time":blog_time,"gender":gender,'mood':mood,"location":location}

bmgl = pd.DataFrame(bmgl)  
bmgl['blog_time'] = pd.to_datetime(bmgl['blog_time'])
bmgl['blog_time'] = bmgl['blog_time'].apply(lambda x : x.strftime('%Y-%m-%d'))
bmgl = bmgl.sort_values(by='blog_time',ascending=True)
bmgl.to_csv(f'C:/Users/Lenovo/yan/D/金融数据整理（2021）/bmgl/bmgl_sh.csv',index=False, encoding='utf_8_sig')

# %% [markdown]
# 证券

# %%
blog_time = []
mood = []
gender = []
location = []

for line in open('C:/Users/Lenovo/yan/D/金融数据整理（2021）/原始数据/证券.txt', encoding="utf8"):
    w = json.loads(line)
    for key in w.keys():
        if key == 'w:created_at':
            blog_time.append(w[key])
        elif key == 'w:mood':
            mood.append(w[key])
        elif key == 'w:gender':
            gender.append(w[key])
        elif key == 'w:location':
            location.append(w[key])

bmgl = {"blog_time":blog_time,"gender":gender,'mood':mood,"location":location}

bmgl = pd.DataFrame(bmgl)  
bmgl['blog_time'] = pd.to_datetime(bmgl['blog_time'])
bmgl['blog_time'] = bmgl['blog_time'].apply(lambda x : x.strftime('%Y-%m-%d'))
bmgl = bmgl.sort_values(by='blog_time',ascending=True)
bmgl.to_csv('C:/Users/Lenovo/yan/D/金融数据整理（2021）/bmgl/bmgl_se.csv',index=False, encoding='utf_8_sig')

# %% [markdown]
# 合并文件

# %%
import glob


def mkdir(path):
    folder = os.path.exists(path)
    if not folder:  # 判断是否存在文件夹如果不存在则创建为文件夹
        os.makedirs(path)  # makedirs 创建文件时如果路径不存在会创建这个路径

def merge_csv(csv_path, save_path, save_name):
    inputfile = csv_path + '/*.csv'
    outputfile = os.path.join(save_path, save_name)
    mkdir(save_path)
    csv_list = glob.glob(inputfile)

    # 先读取第一个文件
    filepath = csv_list[0]
    df = pd.read_csv(filepath)
    df = df.to_csv(outputfile, index=False, header=True)
    for i in range(1, len(csv_list)):
        filepath = csv_list[i]
        df = pd.read_csv(filepath)
        df = df.to_csv(outputfile, index=False, header=False, mode='a+')
        print(filepath + 'over!')

# %% [markdown]
# 查看文件长度

# %%
csv_path = 'bmgl/'
save_path = 'bmgl/'
save_name = 'merge_bmgl.csv'
merge_csv(csv_path, save_path, save_name)
# Out:
# bmgl\bmgl_se.csvover!
# bmgl\bmgl_sh.csvover!
# bmgl\bmgl_sm.csvover!
# bmgl\bmgl_st.csvover!
# bmgl\bmgl_sz.csvover!

# %%
base_pth = 'bmgl/'
file_list = os.listdir(base_pth)

for f in file_list:
    csv_temp = pd.read_csv(os.path.join(base_pth, f))
    
    print(f"{f}: {csv_temp.shape}")
# Out:
# bmgl_ingre.csv: (1312, 4)
# bmgl_se.csv: (2871681, 4)
# bmgl_sh.csv: (1377839, 4)
# bmgl_sm.csv: (7126608, 4)
# bmgl_st.csv: (9146803, 4)
# bmgl_sz.csv: (304224, 4)
# merge_bmgl.csv: (20828467, 4)

# %%
merge_bmgl = pd.read_csv('bmgl/merge_bmgl.csv')

# %% [markdown]
# 按天进行文件分割（用pycharm做）

# %%
# x_head_key = ['blog_time', 'gender','mood','location']
# df = pd.read_csv('bmgl/merge_bmgl.csv', header=0,encoding='utf-8')
# df.columns = x_head_key


# # 对数据进行分组处理
# grouped = df.groupby(x_head_key[0])  # 根据日期划分数据

# file = 'bmgl/day_bmgl/'

# for value, group in grouped:
#     filename = str(value) + '.csv'
#     try:
#         f = open(filename, 'w')
#         if f:
#             # 清空文件内容
#             f.truncate()

#         # 将新数据写入文件
#         group.to_csv(filename, header=x_head_key, index=False, mode='ab+')
#     except UnicodeEncodeError:
#         print("编码错误, 该数据无法写到文件中, 直接忽略该数据")

# %% [markdown]
# 按天计算性别次数(用pycharm)

# %%
# # 将文件gender列数据放入列表list_data中
# import csv
# from collections import Counter

# def get_date(pth):
#     splited_str = pth.split('/')[-1]
#     dot_index = splited_str.index('.')

#     date_result = splited_str[:dot_index]

#     return date_result

# def count_gender(csvfile):
#     def read_file_csv(csvfile):
#         list_data = []
#         with open(csvfile, encoding='utf-8') as csvfile:
#             csv_reader = csv.reader(csvfile)
#             for row in csv_reader:  # 将csv 文件中的数据保存到list_data中
#                 list_data.append(row[1])
#                 blog_time = row[0][0]
#         return list_data  # 返回想要获取的那一列数据


#     result_dict = Counter(read_file_csv(csvfile))
#     result_dict = {
#         'date': get_date(csvfile),
#         'f': result_dict['f'],
#         'm': result_dict['m']
#     }

#     target = pd.DataFrame(result_dict, index=[-1])
#     #count = target.to_csv('count_gender.csv', encoding='utf-8-sig')
#     return target


# base_pth = 'C:/Users/Lenovo/yan/D/金融数据整理（2021）/bmgl/day_bmgl/'
# csv_list = os.listdir(base_pth)
# csv_list = [base_pth+i for i in csv_list]

# target = pd.DataFrame(columns=[
#         'date', 'f','m'
#     ])

# for _csv in csv_list:
#     try:
#         print(f"正在执行:{_csv}")
#         temp_csv = count_gender(_csv)
#         target = target.append(temp_csv, ignore_index=True)
#     except Exception as e:
#         print(f"出错了:{e}")
# target.to_csv('C:/Users/Lenovo/yan/D/金融数据整理（2021）/bmgl/count_gender.csv', index=False)

# # if __name__ == '__main__':
# #     print(count_gender('C:/Users/Lenovo/yan/D/金融数据整理（2021）/bmgl/day_bmgl/2014-12-01.csv'))

# %% [markdown]
# 考虑将厌恶情绪与性别结合起来，仍用pycharm计算结果

# %%
# def read_file_csv(csvfile):
#     gender_data = []

#     with open(csvfile, encoding='utf-8') as csvfile:
#         csv_reader = csv.reader(csvfile)
#         for row in csv_reader:  # 将csv 文件中的数据保存到list_data中
#             if row[2] == '1':
#                 gender_data.append(row[1])
#                 blog_time = row[0][0]
#         return gender_data  # 返回想要获取的那一列数据

# %% [markdown]
# 回归分析

# %%
def union_data(x_data, y_data, posi):
    """
    间隔为0.2
    """
    interval = 0.2
    X = []
    Y = []
    if posi == 1:
        x_y = {round(i, 1): [] for i in np.arange(0, 6.4 + interval, interval)}
    elif posi == -1:
        x_y = {round(i, 1): [] for i in np.arange(-8.0, interval, interval)}
    
    for x, y in zip(x_data, y_data):
        k = round(int(x / interval) * interval, 1) # 取 interval
        try:
            x_y[k].append(y)
        except:
            pass
    
    for x in x_y:
        y_list = x_y[x]
        if y_list:
            y = np.array(y_list).mean()
        else:
            y = -1
#         x_y[x] = y
        X.append(x)
        Y.append(y)
    
    last = 10000
    for i in range(len(Y)): 
        if Y[i] != -1:
            last = Y[i]
        if Y[i] == -1: # 找到第一个0
            for j in range(i+1, len(Y)): 
                if Y[j] != -1: # 找到最近的一个非0
                    now = Y[j]
                    break
            else:
                for m in range(i, len(Y)):
                    Y[m] = last
                return X, Y

            gap = (now - last) / (j - i + 1)
            for k in range(i, j):
                Y[k] = last + gap * (k - i + 1)
    return X, Y


def my_line(x_n, y_n, x, y, **kw):
    '''
    牛熊市下用户行为的差异
    :param x_n: 收益率小于0
    :param y_n:
    :param x: 收益率大于0
    :param y:
    :return:
    '''

    def linear(input_x, input_y):
        '''
        线性回归
        :param x:
        :param y:
        :return: 拟合参数
        '''
        clf = LinearRegression()
        X = [[i] for i in input_x.tolist()]
        y = input_y.tolist()
        clf.fit(X, y)
        return clf.coef_[0], clf.intercept_, clf.score(X, y)
    
    def liner_model(k, b):
        def model(x):
            return b + k * x
        return model
    
    
    res = {}
    plt.figure(figsize=(9, 5))
    
    plt.scatter(x_n, y_n, alpha=0.3, c = '#4ea64e', label='$r < 0$')
    plt.scatter(x, y, alpha=0.3, c = '#fb5050',label='$r > 0$')
    
    union_x_n, union_y_n = union_data(x_n, y_n, posi=-1)
    union_x, union_y = union_data(x, y, posi=1)
    #plt.plot(union_x_n, union_y_n, c='grey')
    #plt.plot(union_x, union_y, c='grey')
    
    # 正
    print('return > 0')
    
    # 画拟合直线
    print('---------- 收益率 < 0 ----------')
    a_n, b_n, r2 = linear(x_n, y_n)
    print('相关性：', x_n.corr(y_n))
    print('参数：', a_n, b_n)
    res['k_n'] = a_n
    res['b_n'] = b_n
    print('R^2：', r2)
    mod_n = liner_model(a_n, b_n)
    p_0 = mod_n(0)
    p_8 = mod_n(-8)
    p_4 = mod_n(4)
    plt.plot([-8, 0], [p_8, p_0], '-', c = '#008000', linewidth=2)
    plt.plot([0, 4], [p_0, p_4], '--', c = '#008000', linewidth=2)
    
    pars = lmfit.Parameters()
    pars.add_many(('k', 1000), ('b', 1000))
    def residual(p):
        return p['k'] * x_n + p['b'] - y_n

    mini = lmfit.Minimizer(residual, pars)
    result = mini.minimize()
    print(lmfit.fit_report(result.params))

    print('---------- 收益率 > 0 ----------')
    a, b, r2 = linear(x, y)
    print('相关性：', x.corr(y))
    print('参数：', a, b)
    res['k'] = a
    res['b'] = b
    print('R^2：', r2)
    mod = liner_model(a, b)
    p_0 = mod(0)
    p_8 = mod(8)
    plt.plot([0, 8], [p_0, p_8], '-',c = '#ff0000',linewidth=1.8)
    
    pars = lmfit.Parameters()
    pars.add_many(('k', -1000), ('b', 1000))
    def residual(p):
        return p['k'] * x + p['b'] - y

    mini = lmfit.Minimizer(residual, pars)
    result = mini.minimize()
    print(lmfit.fit_report(result.params))
    
    
    print('- - - - - - - - - - 损失厌恶指数 - - - - - - - - - -')
    print('斜率比例：', a_n / a)
    the_point = (b - b_n) / (a_n - a)
    print('平衡点：', the_point)
    formatter = ticker.ScalarFormatter(useMathText=True)
    formatter.set_scientific(True)
    plt.scatter(the_point, mod(the_point), c='k', linewidths=3, zorder=100, label='balance point')
    
    plt.xlim(-9, 9)
    plt.xlabel('$r$', fontsize=15)
    if 'ylabel' in kw:
        plt.ylabel(kw['ylabel'], fontsize=15)
    else:
        plt.ylabel('amount of tweets', fontsize=15)
    plt.legend(loc=1)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=12)
#     plt.grid()
    if 'out' in kw:
        plt.savefig(kw['out'], dpi=300)
    plt.savefig('C:/Users/Lenovo/Desktop/su_image.svg')
    plt.show()
    plt.close('all')
    
    
    print('收益率为0：', mod_n(0) / mod(0))
    print('收益率为1：', mod_n(-1) / mod(1))
    print('收益率为2：', mod_n(-2) / mod(2))
    print('收益率为4：', mod_n(-4) / mod(4))
    print('收益率为6：', mod_n(-6) / mod(6))
    
    plt.figure(figsize=(6, 4))
    plt.xlabel('$r$', fontsize=15)
#     plt.xlim(0, 10)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    x = np.arange(0, 8, 0.1)
    y = [mod_n(-i) / mod(i) for i in x]
    res['y_ratio'] = y
    plt.plot(x, y)
    plt.show()
    plt.close('all')
    
    
    plt.figure(figsize=(6, 4))
    plt.xlabel('$r$', fontsize=15)
#     plt.xlim(0, 10)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)    
    len_union_x = len(union_x)
#     print(union_x_n, union_y_n)
#     print(union_x, union_y)
    union_y_n.reverse()
    union_ratio = [union_y_n[i] / union_y[i] for i in range(len_union_x)]
    res['union_y_ratio'] = union_ratio
    res['union_x'] = union_x
    plt.plot(union_x, union_ratio)
#     plt.legend(loc=1)
    plt.show()
    plt.close('all')
    
    res['union_y_n'] = union_y_n
    res['union_y'] = union_y 
    
    
    # 返回可以评估
    res['ratio'] = a_n / a
    res['point'] = the_point
    

    
    return res

# %%
def my_nonlinear_model(p):
    def this_model(x):
        return p['A1'] * (x ** p['A2']) + p['b']
    return this_model


def my_nonline(x_n, y_n, x, y, **kw):
    """
    拟合损失厌恶曲线
    注意：需要初始化参数
    """
    plt.figure(figsize=(12, 5))
    plt.scatter(x_n, y_n, alpha=0.3, label='$r < 0$')
    plt.scatter(x, y, alpha=0.3, label='$r > 0$')
    
    union_x_n, union_y_n = union_data(x_n, y_n, posi=-1)
    union_x, union_y = union_data(x, y, posi=1)
    plt.plot(union_x_n, union_y_n, c='grey')
    plt.plot(union_x, union_y, c='grey')
    
    # 正
    print('return > 0')
    pars = lmfit.Parameters()
    pars.add_many(('A1', 1000), ('A2', 1), ('b', 4000))
    def residual(p):
        return p['A1'] * (x ** p['A2']) + p['b'] - y

    mini = lmfit.Minimizer(residual, pars)
    result = mini.minimize()
    print(lmfit.fit_report(result.params))
    # ci1 = lmfit.conf_interval(mini, result)
    # lmfit.printfuncs.report_ci(ci1)
    
    mod_1 = my_nonlinear_model(result.params)
    x_fit = np.arange(0, 6, 0.1)
    y_fit = [mod_1(x) for x in x_fit]
    plt.plot(x_fit, y_fit, 'r-', linewidth=2)

    print('- * - ' * 15)

    # 负
    print('return < 0')
    pars = lmfit.Parameters()
    pars.add_many(('A1', -kw['k_n']), ('A2', 1.5), ('b', kw['b_n']))
    x_n = [-x for x in x_n]
    def residual(p):
        return p['A1'] * (x_n ** p['A2']) + p['b'] - y_n

    mini = lmfit.Minimizer(residual, pars)
    result = mini.minimize()
    print(lmfit.fit_report(result.params))
    # ci2 = lmfit.conf_interval(mini, result)
    # lmfit.printfuncs.report_ci(ci2)

    mod_2 = my_nonlinear_model(result.params)
    x_fit = np.arange(0, 8, 0.1)
    y_fit = [mod_2(x) for x in x_fit]
    x_fit = [-x for x in x_fit]
    plt.plot(x_fit, y_fit, '-', c='purple', linewidth=2)
    
    
    # 画图配置及输出
    plt.xlim(-9, 9)
    plt.xlabel('$r$', fontsize=15)
    if 'ylabel' in kw:
        plt.ylabel(kw['ylabel'], fontsize=15)
    else:
        plt.ylabel('amount of tweets', fontsize=15)
    plt.legend(loc=1)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=12)
#     plt.grid()
    if 'out' in kw:
        plt.savefig(kw['out'], dpi=300)
    plt.show()
    plt.close('all')
    
    # 比值
    print('收益率为0.5：', mod_2(0.5) / mod_1(0.5))
    print('收益率为1：', mod_2(1) / mod_1(1))
    print('收益率为2：', mod_2(2) / mod_1(2))
    print('收益率为4：', mod_2(4) / mod_1(4))
    print('收益率为6：', mod_2(6) / mod_1(6))
    

    plt.figure(figsize=(6, 4))
    plt.xlabel('$r$', fontsize=15)
#     plt.xlim(0, 10)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    x = np.arange(0, 8, 0.1)
    y = [mod_2(i) / mod_1(i) for i in x]
    kw['non_y_ratio'] = y
    plt.plot(np.arange(0, 10, 1), [1] * 10)
    plt.plot(x, y)
    plt.plot(kw['union_x'], kw['union_y_ratio'])
#     plt.legend(loc=1)
    plt.plot(np.arange(0, 10, 1), [1] * 10, alpha=0.1, linewidth=4)
    plt.show()
    plt.close('all')
    
    return kw

# %%
# 合并线性和非线性分析

def my_analysis(x_n, y_n, x, y, **kw):
    res = my_line(x_n, y_n, x, y, **kw)
    res = dict(kw, **res)
    res = my_nonline(x_n, y_n, x, y, **res)
    return res

# %%
olhc_gender = pd.read_csv('C:/Users/Lenovo/yan/D/金融数据整理（2021）/bmgl/gender/olhc_gender.csv')

# %% [markdown]
# 性别变量

# %%
print("收益率与女性")
x_n = olhc_gender.close[olhc_gender.close<0]
y_n = olhc_gender.f[olhc_gender.close<0]
x = olhc_gender.close[olhc_gender.close>0]
y = olhc_gender.f[olhc_gender.close>0]
my_analysis(x_n, y_n, x, y, hi='Kay')
pass
# Out:
# 收益率与女性
# return > 0
# ---------- 收益率 < 0 ----------
# 相关性： -0.45248333086823345
# 参数： -1065.592568535506 9351.61506320765
# R^2： 0.20474116471361115
# [[Variables]]
#     k: -1065.59257 +/- 151.169504 (14.19%) (init = 1000)
#     b:  9351.61506 +/- 377.067033 (4.03%) (init = 1000)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(k, b) = 0.658
# ---------- 收益率 > 0 ----------
# 相关性： 0.15688335895752883
# 参数： 430.8684205981803 8785.735225583325
# R^2： 0.024612388317797107
# [[Variables]]
#     k:  430.868421 +/- 170.528175 (39.58%) (init = -1000)
#     b:  8785.73523 +/- 311.361252 (3.54%) (init = 1000)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(k, b) = -0.734
# - - - - - - - - - - 损失厌恶指数 - - - - - - - - - -
# 斜率比例： -2.473127566546023
# 平衡点： 0.3781453988666403
# 收益率为0： 1.0644089336970377
# 收益率为1： 1.1302653376072072
# 收益率为2： 1.1902392793464296
# 收益率为4： 1.2954338862763717
# 收益率为6： 1.3846843368825887
# return > 0
# [[Variables]]
# ...

# %%
print("收益率与男性")
x_n = olhc_gender.close[olhc_gender.close<0]
y_n = olhc_gender.m[olhc_gender.close<0]
x = olhc_gender.close[olhc_gender.close>0]
y = olhc_gender.m[olhc_gender.close>0]
my_analysis(x_n, y_n, x, y, hi='Kay')
pass
# Out:
# 收益率与男性
# return > 0
# ---------- 收益率 < 0 ----------
# 相关性： -0.5012343655383533
# 参数： -2823.3133149524188 24911.872156649853
# R^2： 0.25123588919663564
# [[Variables]]
#     k: -2823.31331 +/- 350.842413 (12.43%) (init = 1000)
#     b:  24911.8722 +/- 875.117695 (3.51%) (init = 1000)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(k, b) = 0.658
# ---------- 收益率 > 0 ----------
# 相关性： 0.2386520965214787
# 参数： 1510.4239427172226 23472.385100465413
# R^2： 0.05695482317409706
# [[Variables]]
#     k:  1510.42394 +/- 386.402202 (25.58%) (init = -1000)
#     b:  23472.3851 +/- 705.517864 (3.01%) (init = 1000)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(k, b) = -0.734
# - - - - - - - - - - 损失厌恶指数 - - - - - - - - - -
# 斜率比例： -1.8692191212709024
# 平衡点： 0.3321583590783923
# 收益率为0： 1.061326833639752
# 收益率为1： 1.1101708148055798
# 收益率为2： 1.1534454403061503
# 收益率为4： 1.2267068581364475
# 收益率为6： 1.2863637218709845
# return > 0
# [[Variables]]
# ...

# %% [markdown]
# 厌恶情绪与性别变量

# %%
print("收益率与具有厌恶情绪的女性")
x_n = olhc_gender.close[olhc_gender.close<0]
y_n = olhc_gender.f_disgust[olhc_gender.close<0]
x = olhc_gender.close[olhc_gender.close>0]
y = olhc_gender.f_disgust[olhc_gender.close>0]
my_analysis(x_n, y_n, x, y, hi='Kay')
pass
# Out:
# 收益率与具有厌恶情绪的女性
# return > 0
# ---------- 收益率 < 0 ----------
# 相关性： -0.40920656029632574
# 参数： -114.41592711692786 1146.1043328989476
# R^2： 0.16745000898955076
# [[Variables]]
#     k: -114.415927 +/- 18.3641319 (16.05%) (init = 1000)
#     b:  1146.10433 +/- 45.8062535 (4.00%) (init = 1000)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(k, b) = 0.658
# ---------- 收益率 > 0 ----------
# 相关性： 0.23851088493058373
# 参数： 90.56953468773139 1153.7538774081581
# R^2： 0.056887442230370455
# [[Variables]]
#     k:  90.5695347 +/- 23.1843774 (25.60%) (init = -1000)
#     b:  1153.75388 +/- 42.3315191 (3.67%) (init = 1000)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(k, b) = -0.734
# - - - - - - - - - - 损失厌恶指数 - - - - - - - - - -
# 斜率比例： -1.2632937500608217
# 平衡点： -0.03731749774771895
# 收益率为0： 0.9933698645274374
# 收益率为1： 1.0130165901907322
# 收益率为2： 1.0299973420682649
# 收益率为4： 1.0578721453586828
# 收益率为6： 1.0797967931578998
# return > 0
# [[Variables]]
# ...

# %%
print("收益率与具有厌恶情绪的男性")
x_n = olhc_gender.close[olhc_gender.close<0]
y_n = olhc_gender.m_disgust[olhc_gender.close<0]
x = olhc_gender.close[olhc_gender.close>0]
y = olhc_gender.m_disgust[olhc_gender.close>0]
my_analysis(x_n, y_n, x, y, hi='Kay')
pass
# Out:
# 收益率与具有厌恶情绪的男性
# return > 0
# ---------- 收益率 < 0 ----------
# 相关性： -0.37830816213954593
# 参数： -221.53967571143636 3281.3561935380076
# R^2： 0.1431170655414007
# [[Variables]]
#     k: -221.539676 +/- 39.0200568 (17.61%) (init = 1000)
#     b:  3281.35619 +/- 97.3290017 (2.97%) (init = 1000)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(k, b) = 0.658
# ---------- 收益率 > 0 ----------
# 相关性： 0.28781587885148896
# 参数： 220.97004081972366 3167.8927441106925
# R^2： 0.08283798011905519
# [[Variables]]
#     k:  220.970041 +/- 46.2254787 (20.92%) (init = -1000)
#     b:  3167.89274 +/- 84.4014361 (2.66%) (init = 1000)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(k, b) = -0.734
# - - - - - - - - - - 损失厌恶指数 - - - - - - - - - -
# 斜率比例： -1.0025778829093734
# 平衡点： 0.2564089446820662
# 收益率为0： 1.0358166953847319
# 收益率为1： 1.033649366042824
# 收益率为2： 1.0317473757768618
# 收益率为4： 1.0285657640839339
# 收益率为6： 1.026009951917923
# return > 0
# [[Variables]]
# ...
